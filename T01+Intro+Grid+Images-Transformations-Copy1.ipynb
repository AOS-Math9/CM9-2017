# %% [markdown]
# ### I. The Original Image with an xy Grid:
#
# #### Directions:  Draw an xy Grid and create a matrix for a origin centered figure ready for transformations
#
# Example:  fmatrix = [[0,0], [1,0], [1,2], [2,2], [2,3], [1,3], [1,4], [3,4], [3,5], [0,5], [0,0]]

# %% [markdown]
# The Original Image with an xy Grid:
# fmatrix = [[0,0],
#           [1,0],
#           [1,2],
#           [2,2],
#           [2,3],
#           [1,3],
#           [1,4],
#           [3,4],
#           [3,5],
#           [0,5],
#           [0,0]]
#           <img src='https://drive.google.com/uc?export=view&id=0B1r5pArucmPrVDRzZi1xVXc4ME0' alt="Original" width="350">

# %%
from turtle import *

# from tkinter import *
# t = Turtle()
# screen = Screen()
# screen.setup(850, 850)
# screen.bgcolor("LightYellow")

colormode(255)
clear()

def bluelines():
    speed(0)
    color(0,255,255)                       # Sets CYAN as color
    
    for i in range(21):                     # Vertical Lines
        pu()
        goto(-10+i,-10)
        pd()
        goto(-10+i,10)
        pu()
        
    for j in range(21):                    # Horizontal Lines
        pu()
        goto(-10,-10+j)
        pd()
        goto(10,-10+j)
        pu()
    

def setup():
                          # Draws an x-y grid for better visualization
    speed(0)                               # Check out the speed function 
    setworldcoordinates (-15,-15,15,15)    # Assuming these are in pixels ... really
    setposition(0,0)
    bluelines()
    setpos(0,0)
    setheading(0)                          # Set direction to default ... face East or positve x
    pd()                                   # Pen Down to start writing
    color("Black")                         # Set the line color for grid pad
    bgcolor("LightYellow")
    
    for i in range(4):
        setpos(0,0)
        fd(10)
        rt(90)
        
    pu()                                   # Pen Up - stop writing
    setpos(0,0)

    


# Creates the Figure (F) using points in a Matrix

fmatrix = [[0,0],
          [1,0],
          [1,2],
          [2,2],
          [2,3],
          [1,3],
          [1,4],
          [3,4],
          [3,5],
          [0,5],
          [0,0]]

def drawf(matA):
    pensize(2)
    pu()
    goto(0,0)
    pd()
    
    for point in matA:
        goto(point[0],point[1])

        
setup()
drawf(fmatrix)

print(fmatrix)        

exitonclick()

# %% [markdown]
# ### II. Origin Centered Rotation - Using Matrix Basis Theorem:
#
# #### Directions:  Create an origin centered Rotation of original image by applying a matrix operation
#
# Positive Rotations: <br>
# rot = 0 [[1, 0], [0, 1]] <br>
# rot = 90 [[0, 1], [-1, 0]] <br>
# rot = 180 [[-1, 0], [-1, 0]] <br>
# rot = 270 [[0, -1], [1, 0]] <br>

# %% [markdown]
# <table><tr><td><img src='https://drive.google.com/uc?export=view&id=0B1r5pArucmPrdE41SWwtaDV3enM' alt="rot90" width="350"> </td><td><img src='https://drive.google.com/uc?export=view&id=0B1r5pArucmPrckhZcGlndndnbzg' alt="rot180" width="350"></td><td><img src='https://drive.google.com/uc?export=view&id=0B1r5pArucmPrRUtVOFNEVm93ZDQ' alt="Rot270" width="350"> </td></tr></table>

# %% [markdown]
# ### III. Scaling and Size Transformations - Using Matrix Basis Theorem:
#
# #### Directions:  Create scalings of original image by applying a matrix operation
#
# Size Transformations and Scalings: <br>
# S(x,y) = (2x, 2y) = [[2, 0], [0, 2]] <br>
# S(x,y) = (-2x, -2y)= [[2, 0], [0, 2]] <br>
# S(x,y) = (3x, y)= [[3, 0], [0, 1]] <br>

# %% [markdown]
# <table><tr><td><img src='https://drive.google.com/uc?export=view&id=0B1r5pArucmPrWWdfdlpSRURDcHM' alt="(2x,2y)" width="350"> </td><td><img src='https://drive.google.com/uc?export=view&id=0B1r5pArucmPrYktHMzJ1VHExbFE' alt="(-2x,-2y)" width="350"> </td><td><img src='https://drive.google.com/uc?export=view&id=0B1r5pArucmPrc1doOERibl9WZXc' alt="(x,3y)" width="350"> </td></tr></table>

# %% [markdown]
# ### IV. Origin Centered Reflections - Using Matrix Basis Theorem:
#
# #### Directions:  Create reflections of original image by applying a matrix operation
#
# Reflections over x-axis and y-axis: <br>
# S(x,y) = (-x, y) = [[0, 1], [1, 0]]<br>
# S(x,y) = (x, -y)= [[0, -1], [1, 0]]<br>
#
# Reflections over y = x and y = -x : <br>
# S(x,y) = (y, x) = [[0, 1], [1, 0]]<br>
# S(x,y) = (-y, x)= [[0, -1], [1, 0]]<br>

# %% [markdown]
# <table><tr><td><img src='https://drive.google.com/uc?export=view&id=0B1r5pArucmPrWWpMTFlPV1dhVUU' alt="DSP" width="350"> </td><td><img src='https://drive.google.com/uc?export=view&id=0B1r5pArucmPrZThKTHIxeDg1N0U' alt="DSP" width="350"> </td></tr></table>
#
#
#
# <table><tr><td><img src='https://drive.google.com/uc?export=view&id=0B1r5pArucmPrNkxNa0lvaUdxNmM' alt="DSP" width="350"> </td><td><img src='https://drive.google.com/uc?export=view&id=0B1r5pArucmPraDNTYUlSQkwwOTA' alt="DSP" width="350"> </td></tr></table>

# %%
from turtle import *

# from tkinter import *
# t = Turtle()
# screen = Screen()
# screen.setup(850, 850)
# screen.bgcolor("LightYellow")

colormode(255)
clear()

def bluelines():
    speed(0)
    color(0,255,255)                       # Sets CYAN as color
    
    for i in range(21):                     # Vertical Lines
        pu()
        goto(-10+i,-10)
        pd()
        goto(-10+i,10)
        pu()
        
    for j in range(21):                    # Horizontal Lines
        pu()
        goto(-10,-10+j)
        pd()
        goto(10,-10+j)
        pu()
    

def setup():
                          # Draws an x-y grid for better visualization
    speed(0)                               # Check out the speed function 
    setworldcoordinates (-15,-15,15,15)    # Assuming these are in pixels ... really
    setposition(0,0)
    bluelines()
    setpos(0,0)
    setheading(0)                          # Set direction to default ... face East or positve x
    pd()                                   # Pen Down to start writing
    color("Black")                         # Set the line color for grid pad
    bgcolor("LightYellow")
    
    for i in range(4):
        setpos(0,0)
        fd(10)
        rt(90)
        
    pu()                                   # Pen Up - stop writing
    setpos(0,0)

    


# Creates the Figure (F) using points in a Matrix

fmatrix = [[0,0],
          [1,0],
          [1,2],
          [2,2],
          [2,3],
          [1,3],
          [1,4],
          [3,4],
          [3,5],
          [0,5],
          [0,0]]

def drawf(matA):
    pu()
    goto(0,0)
    pd()
    
    for point in matA:
        goto(point[0],point[1])

# Here is the key part:  Return the product of two matrices a and b        
        
def matMult(a,b):        
    newmatrix = []
    pensize(3)
    
    for i in range(len(a)):
        newmatrix.append([])
        
        for j in range(2):
            newmatrix[i].append(a[i][0]*b[0][j]+a[i][1]*b[1][j])

    return newmatrix


# Define the Transformation Matrix b            

transformationMatrix = [[-1,0],[0,-1]]

# transformationMatrix = list(input("Type in your Transformation Matrix: "))


# Multiply F-matrix= a by Transformation Matrix = b

newmat = matMult(fmatrix, transformationMatrix)
      
# Here is the first transformation        
setup()
drawf(fmatrix)

print(fmatrix)        

speed(250)

pensize(3)
color("blue")
drawf(newmat)

print(newmat)        

# Here is the second transformation

# transformationMatrix = [[0,1],
#                       [-1,0]]

exitonclick()
# Out:
# [[0, 0], [1, 0], [1, 2], [2, 2], [2, 3], [1, 3], [1, 4], [3, 4], [3, 5], [0, 5], [0, 0]]
# [[0, 0], [-1, 0], [-1, -2], [-2, -2], [-2, -3], [-1, -3], [-1, -4], [-3, -4], [-3, -5], [0, -5], [0, 0]]
